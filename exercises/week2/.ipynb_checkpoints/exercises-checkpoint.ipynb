# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Lecture 2 - Finite-dimensional linear inverse problems

# %% [markdown]
# ## Pseudo-inverse
#
# Show that
#
# 1. $KK^\dagger$ is an orthogonal projection on to the range of $K$
# 2. $I - K^\dagger K$ is an orthogonal projection to to the null-space of $K$

# %% [markdown]
# Exercise 1:

# %% [markdown]
# ## Least-squares and minimum-norm solutions:
# Given a system of equations $Ku = f$ with $K\in\mathbb{R}^{m\times n}$:
#
# 1. For $m > n$ and rank($K$) = $n$, show that the pseudo-inverse gives the solution $u = K^\dagger f$ with the smallest residual $\|Ku - f\|_2$
#
# 2. For $m < n$ and rank($K$) = $m$, show that the pseudo-inverse gives the solution $u = K^\dagger f$ with the smallest norm $\|u\|_2$
#
# 3. For $m > n$ and rank($K$) = $r < n$, show that the pseudo-inverse gives the solution that minimizes both $\|Ku - f\|_2$ and $\|u\|_2$.

# %% [markdown]
# Exercise 1:
# Since $K$ is full column rank we have $K^\dagger = (K^TK)^{-1}K^T$.
#
# We need to solve
# $$
# min_u \|Ku-f\| = min_u \|Ku-f\|^2
# $$
# The $u$ that solves this is equal to the $u$ that solves
# $$
# 0 = \grad_u \|Ku-f\|^2 \\
# =\grad_u ((Ku-f)\cdot(Ku-f)) \\
# =\grad_u (Ku\cdot Ku-2f\cdot Ku+f\cdot f) \\
# =\grad_u (u^TK^TKu-2f^TKu+f\cdot f) \\
# =2(K^TKu-f^TK) \\
# =2(K^TKu-K^Tf) \\
# $$
# The $u$ which solves this is
# $$
# u = (K^TK)^{-1}K^Tf = K^\dagger f
# $$
# Exercise 2:
# Since $K$ is full column rank we have $K^\dagger = K^T(KK^T)^{-1}$.
#
# We mininimze the norm of $u$ given $Ku=f$ using the Langrangian
#
# $$
#  L(u) = \|u\|^2 - \lambda^T(Ku-f)
# $$
# We solve this by setting the derivative of the Langrangian to zero.
# $$
# 0 = \frac{\partial L}{\partial u} = 2u^T - \lambda^TK
# $$
# Solving for $u$ in terms of $\lambda$ gives
# $$
# 2u^T = \lambda^TK \\
# u = \frac{1}{2}K^T\lambda
# $$
# Plugging this in
# $$
# Ku=f
# $$
# gives
# $$
# K\frac{1}{2}K^T\lambda = f \\
# \lambda = 2(KK^T)^{-1}f
# $$
# Substituting gives
# $$
# u = \frac{1}{2}K^T\lambda  \\
# = \frac{1}{2}K^T2(KK^T)^{-1}f \\
# = K^T(KK^T)^{-1}f \\
# $$

# %% [markdown]
# ## Gravity surveying
#
# We can estimate the density distribution in the subsurface by measuing the local gravitational pull. The density profile $u(x)$ is related to such measurements by a linear operator
# $$Ku(x) = \int_0^1 \frac{u(x')}{(1 + (x-x')^2)^{3/2}} \mathrm{d}x'.$$
# Upon discretization with stepsize $h = 1/n$, the inverse problem can be cast as a system of $n$ equations in $n$ unknowns $Ku = f$.
#
# 1. Use the code provided below to generate the matrix and compute its SVD (use `np.linalg.svd`)
# 3. Plot the coefficients $\langle u_i, f\rangle$ and the singular values $\sigma_i$ to check the discrete Picard condition. What do you notice ?
#
# 2. Solve the inverse problem for noisy data using the (regularized) pseudo-inverse; compute the optimal $\alpha$ by computing the bias and variance components of the error.

# %%
def getK(n):
    h = 1/n;
    x = np.linspace(h/2,1-h/2,n)
    xx,yy = np.meshgrid(x,x)
    K = h/(1 + (xx - yy)**2)**(3/2)
    
    return K,x

# %%
n = 100
delta = 1e-2
K,x = getK(n)

u = np.sin(np.pi*x) + 0.5*np.sin(2*np.pi*x)
f = K@u

noise = np.random.randn(n)
f_delta = f + delta*noise

fig, axs = plt.subplots(2,1,sharex=True)

axs[0].plot(x,u)
axs[0].set_ylabel('u(x)')

axs[1].plot(x,f,label='clean data')
axs[1].plot(x,f_delta,label='noisy data')

axs[1].set_xlabel('x')
axs[1].set_ylabel('f(x)')
axs[1].legend()

U, S, V = np.linalg.svd(K)

np.set_printoptions(formatter={'float': lambda x: "{0:0.3f}".format(x)})
print("SVD of K:")
# print("U: {}".format(U))
# print("S: {}".format(S))
# print("V: {}".format(V))

plt.figure()
plt.title("Picard global")
plt.plot(np.abs(np.transpose(U)@f))
plt.plot(S)
plt.legend(["Fourier", "Singular values"])

plt.figure()
plt.title("Picard start")
plt.plot(np.abs(np.transpose(U)@f))
plt.plot(S)
plt.ylim((0,5))
plt.xlim((0,10))
plt.legend(["Fourier", "Singular values"])

plt.figure()
plt.title("Picard zoomed")
plt.plot(np.abs(np.transpose(U)@f))
plt.plot(S)
plt.ylim((0,0.01))
plt.xlim((0,10))
plt.legend(["Fourier", "Singular values"])
plt.show()


u_reconstructed = np.linalg.pinv(K)@f
u_reconstructed_noisy = np.linalg.pinv(K)@f_delta
plt.figure()
plt.title("U compared to U reconstructed")
plt.plot(u)
plt.plot(u_reconstructed)
plt.plot(u_reconstructed_noisy)
plt.legend(["u", "u reconstructed - noiseless", "u reconstructed - noisy"])
plt.show()
# Out:
# SVD of K:
